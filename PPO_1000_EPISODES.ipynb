# %%
import tensorflow as tf
import numpy as np
import gym
import time
import matplotlib.pyplot as plt
# Out:
# 2024-12-20 09:45:34.086789: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-20 09:45:34.097308: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-20 09:45:34.120248: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734687934.166741  147725 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734687934.178330  147725 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-20 09:45:34.223801: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
env = gym.make("CartPole-v1")

# %%
EPISODES = 1000
GAMMA = 0.99
LR = 0.0003
BATCH_SIZE = 64
UPDATE_STEPS = 10
EPSILON = 0.2
VALUE_LOSS_WEIGHT = 0.5
ENTROPY_WEIGHT = 0.01

# %%
class PPOModel(tf.keras.Model):
    def __init__(self):
        super(PPOModel, self).__init__()
        self.dense1 = tf.keras.layers.Dense(128, activation="relu")
        self.dense2 = tf.keras.layers.Dense(128, activation="relu")
        self.policy_logits = tf.keras.layers.Dense(env.action_space.n)
        self.value = tf.keras.layers.Dense(1)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        logits = self.policy_logits(x)
        value = self.value(x)
        return logits, value

# %%
model = PPOModel()
optimizer = tf.keras.optimizers.Adam(learning_rate=LR)
# Out:
# 2024-12-20 09:45:43.323011: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
start_time = time.time()

reward_list = []
for episode in range(EPISODES):
    state = env.reset()[0]
    done = False
    total_reward = 0
    states = []
    actions = []
    rewards = []
    dones = []
    old_log_probs = []
    
    while not done:
        state_tensor = tf.convert_to_tensor(state, dtype=tf.float32)
        state_tensor = tf.expand_dims(state_tensor, 0)
        
        logits, value = model(state_tensor)
        prob = tf.nn.softmax(logits)
        
        dist = tf.random.categorical(logits, 1)
        action = dist.numpy()[0][0]
        log_prob = tf.math.log(prob[0, action])
        
        next_state, reward, done, _, _ = env.step(action)
        
        states.append(state)
        actions.append(action)
        rewards.append(reward)
        dones.append(done)
        old_log_probs.append(log_prob)
        
        state = next_state
        total_reward += reward
    
    discounted_rewards = []
    discounted_reward = 0
    for reward, done in zip(reversed(rewards), reversed(dones)):
        if done:
            discounted_reward = 0
        discounted_reward = reward + GAMMA * discounted_reward
        discounted_rewards.insert(0, discounted_reward)

    states_tensor = tf.convert_to_tensor(states, dtype=tf.float32)
    old_values = model(states_tensor)[1]
    advantages = tf.convert_to_tensor(discounted_rewards, dtype=tf.float32) - old_values.numpy().flatten()

    actions = tf.convert_to_tensor(actions, dtype=tf.int32)
    old_log_probs = tf.convert_to_tensor(old_log_probs, dtype=tf.float32)
    discounted_rewards = tf.convert_to_tensor(discounted_rewards, dtype=tf.float32)
    advantages = tf.convert_to_tensor(advantages, dtype=tf.float32)

    with tf.GradientTape() as tape:
        logits, value = model(states_tensor)
        prob = tf.nn.softmax(logits)
        dist = tf.random.categorical(logits, 1)
        log_prob = tf.math.log(tf.gather(prob, actions, axis=1, batch_dims=1))

        ratio = tf.exp(log_prob - old_log_probs)
        clipped_ratio = tf.clip_by_value(ratio, 1 - EPSILON, 1 + EPSILON)

        policy_loss = -tf.reduce_mean(tf.minimum(ratio * advantages, clipped_ratio * advantages))
        value_loss = tf.reduce_mean(tf.square(discounted_rewards - value))
        entropy_loss = -tf.reduce_mean(prob * tf.math.log(prob))

        loss = policy_loss + VALUE_LOSS_WEIGHT * value_loss - ENTROPY_WEIGHT * entropy_loss

    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

    if episode % 10 == 0:
        current_time = time.time()
        elapsed_time = current_time - start_time
        print(f"Episode {episode}, Total Reward: {total_reward}, Time: {elapsed_time:.2f} seconds")

    reward_list.append(total_reward)

end_time = time.time()

training_time = end_time - start_time
print(f"Total training time: {training_time:.2f} seconds")
# Out:
# /opt/conda/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 0, Total Reward: 24.0, Time: 0.67 seconds
# Episode 10, Total Reward: 11.0, Time: 3.25 seconds
# Episode 20, Total Reward: 61.0, Time: 6.18 seconds
# Episode 30, Total Reward: 24.0, Time: 8.72 seconds
# Episode 40, Total Reward: 40.0, Time: 11.38 seconds
# Episode 50, Total Reward: 15.0, Time: 13.70 seconds
# Episode 60, Total Reward: 14.0, Time: 16.49 seconds
# Episode 70, Total Reward: 65.0, Time: 22.03 seconds
# Episode 80, Total Reward: 53.0, Time: 25.17 seconds
# Episode 90, Total Reward: 15.0, Time: 27.55 seconds
# Episode 100, Total Reward: 27.0, Time: 30.11 seconds
# Episode 110, Total Reward: 37.0, Time: 32.39 seconds
# Episode 120, Total Reward: 22.0, Time: 35.03 seconds
# Episode 130, Total Reward: 19.0, Time: 37.74 seconds
# Episode 140, Total Reward: 12.0, Time: 39.99 seconds
# Episode 150, Total Reward: 40.0, Time: 42.16 seconds
# Episode 160, Total Reward: 14.0, Time: 44.74 seconds
# Episode 170, Total Reward: 21.0, Time: 47.40 seconds
# Episode 180, Total Reward: 45.0, Time: 50.74 seconds
# Episode 190, Total Reward: 18.0, Time: 53.58 seconds
# Episode 200, Total Reward: 60.0, Time: 56.71 seconds
# Episode 210, Total Reward: 60.0, Time: 59.57 seconds
# Episode 220, Total Reward: 39.0, Time: 62.26 seconds
# Episode 230, Total Reward: 30.0, Time: 65.04 seconds
# Episode 240, Total Reward: 16.0, Time: 67.90 seconds
# Episode 250, Total Reward: 50.0, Time: 71.70 seconds
# Episode 260, Total Reward: 18.0, Time: 75.05 seconds
# Episode 270, Total Reward: 47.0, Time: 79.91 seconds
# Episode 280, Total Reward: 22.0, Time: 84.81 seconds
# Episode 290, Total Reward: 27.0, Time: 88.64 seconds
# Episode 300, Total Reward: 15.0, Time: 91.84 seconds
# Episode 310, Total Reward: 17.0, Time: 95.73 seconds
# Episode 320, Total Reward: 32.0, Time: 99.66 seconds
# Episode 330, Total Reward: 43.0, Time: 103.42 seconds
# Episode 340, Total Reward: 25.0, Time: 107.01 seconds
# Episode 350, Total Reward: 110.0, Time: 111.86 seconds
# Episode 360, Total Reward: 34.0, Time: 115.57 seconds
# Episode 370, Total Reward: 65.0, Time: 120.13 seconds
# Episode 380, Total Reward: 18.0, Time: 123.62 seconds
# Episode 390, Total Reward: 30.0, Time: 127.92 seconds
# Episode 400, Total Reward: 44.0, Time: 131.91 seconds
# Episode 410, Total Reward: 44.0, Time: 136.16 seconds
# Episode 420, Total Reward: 46.0, Time: 143.92 seconds
# Episode 430, Total Reward: 18.0, Time: 148.14 seconds
# Episode 440, Total Reward: 64.0, Time: 153.78 seconds
# Episode 450, Total Reward: 68.0, Time: 157.69 seconds
# Episode 460, Total Reward: 28.0, Time: 162.48 seconds
# Episode 470, Total Reward: 37.0, Time: 166.57 seconds
# Episode 480, Total Reward: 81.0, Time: 171.58 seconds
# Episode 490, Total Reward: 87.0, Time: 176.23 seconds
# Episode 500, Total Reward: 21.0, Time: 180.40 seconds
# Episode 510, Total Reward: 33.0, Time: 185.26 seconds
# Episode 520, Total Reward: 36.0, Time: 188.87 seconds
# Episode 530, Total Reward: 56.0, Time: 192.78 seconds
# Episode 540, Total Reward: 69.0, Time: 197.75 seconds
# Episode 550, Total Reward: 48.0, Time: 204.77 seconds
# Episode 560, Total Reward: 56.0, Time: 210.17 seconds
# Episode 570, Total Reward: 26.0, Time: 214.62 seconds
# Episode 580, Total Reward: 54.0, Time: 220.22 seconds
# Episode 590, Total Reward: 34.0, Time: 225.43 seconds
# Episode 600, Total Reward: 46.0, Time: 230.47 seconds
# Episode 610, Total Reward: 39.0, Time: 235.01 seconds
# Episode 620, Total Reward: 46.0, Time: 240.70 seconds
# Episode 630, Total Reward: 48.0, Time: 245.48 seconds
# Episode 640, Total Reward: 30.0, Time: 249.98 seconds
# Episode 650, Total Reward: 40.0, Time: 254.79 seconds
# Episode 660, Total Reward: 33.0, Time: 263.36 seconds
# Episode 670, Total Reward: 36.0, Time: 268.69 seconds
# Episode 680, Total Reward: 44.0, Time: 273.66 seconds
# Episode 690, Total Reward: 61.0, Time: 278.82 seconds
# Episode 700, Total Reward: 77.0, Time: 284.39 seconds
# Episode 710, Total Reward: 39.0, Time: 288.95 seconds
# Episode 720, Total Reward: 46.0, Time: 293.21 seconds
# Episode 730, Total Reward: 49.0, Time: 297.07 seconds
# Episode 740, Total Reward: 37.0, Time: 301.73 seconds
# Episode 750, Total Reward: 57.0, Time: 307.55 seconds
# Episode 760, Total Reward: 59.0, Time: 312.37 seconds
# Episode 770, Total Reward: 51.0, Time: 321.09 seconds
# Episode 780, Total Reward: 105.0, Time: 329.63 seconds
# Episode 790, Total Reward: 53.0, Time: 333.96 seconds
# Episode 800, Total Reward: 34.0, Time: 340.17 seconds
# Episode 810, Total Reward: 31.0, Time: 345.21 seconds
# Episode 820, Total Reward: 119.0, Time: 349.83 seconds
# Episode 830, Total Reward: 22.0, Time: 356.32 seconds
# Episode 840, Total Reward: 43.0, Time: 361.56 seconds
# Episode 850, Total Reward: 46.0, Time: 367.59 seconds
# Episode 860, Total Reward: 44.0, Time: 371.76 seconds
# Episode 870, Total Reward: 67.0, Time: 378.25 seconds
# Episode 880, Total Reward: 53.0, Time: 385.59 seconds
# Episode 890, Total Reward: 62.0, Time: 390.48 seconds
# Episode 900, Total Reward: 150.0, Time: 396.54 seconds
# Episode 910, Total Reward: 78.0, Time: 401.80 seconds
# Episode 920, Total Reward: 48.0, Time: 406.90 seconds
# Episode 930, Total Reward: 41.0, Time: 411.73 seconds
# Episode 940, Total Reward: 114.0, Time: 417.86 seconds
# Episode 950, Total Reward: 83.0, Time: 423.23 seconds
# Episode 960, Total Reward: 80.0, Time: 429.04 seconds
# Episode 970, Total Reward: 38.0, Time: 434.61 seconds
# Episode 980, Total Reward: 76.0, Time: 442.67 seconds
# Episode 990, Total Reward: 61.0, Time: 448.38 seconds
# Total training time: 453.63 seconds

# %%
plt.plot(reward_list)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward during PPO Training (Maximum Reward: 500)')
plt.show()
